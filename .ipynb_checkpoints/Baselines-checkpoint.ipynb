# %%
# %run Global.ipynb
# %run Helper_Functions.ipynb

# %%
train_df = pd.read_csv(DATASET_DIR + "/train_df_50.csv", keep_default_na=False)
train_df_ohe_selected = pd.read_csv(DATASET_DIR + "/train_df_ohe_selected_50.csv", keep_default_na=False)

y = train_df.iloc[:,-1]
X = train_df.iloc[:,:-1]
X_ohe = train_df_ohe_selected.iloc[:,:-1]

# %% [markdown]
# # Baselines - 0R & 1R

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier

# %%
# 0R
zero_r = DummyClassifier(strategy='most_frequent')
cross_val_report(zero_r, X, y)[1]
# Out:
# DummyClassifier prediction took 0.1587839126586914 seconds.
#
#    3.0_precision  3.0_recall  3.0_f1-score  4.0_precision  4.0_recall  \
# 0            0.0         0.0           0.0       0.702644         1.0
# 1            0.0         0.0           0.0       0.702644         1.0
# 2            0.0         0.0           0.0       0.702644         1.0
# 3            0.0         0.0           0.0       0.702949         1.0
# 4            0.0         0.0           0.0       0.702949         1.0
# 5            0.0         0.0           0.0       0.702949         1.0
# 6            0.0         0.0           0.0       0.702949         1.0
# 7            0.0         0.0           0.0       0.702949         1.0
# 8            0.0         0.0           0.0       0.702515         1.0
# 9            0.0         0.0           0.0       0.702515         1.0
#
#    4.0_f1-score  5.0_precision  5.0_recall  5.0_f1-score  accuracy
# 0      0.825356            0.0         0.0           0.0  0.702644
# ...

# %%
# 1R
one_r = DecisionTreeClassifier(max_depth=1)
cross_val_report(one_r, X_ohe, y)[1]
# Out:
# DecisionTreeClassifier prediction took 0.565352201461792 seconds.
#
#    3.0_precision  3.0_recall  3.0_f1-score  4.0_precision  4.0_recall  \
# 0            0.0         0.0           0.0       0.702644         1.0
# 1            0.0         0.0           0.0       0.702644         1.0
# 2            0.0         0.0           0.0       0.702644         1.0
# 3            0.0         0.0           0.0       0.702949         1.0
# 4            0.0         0.0           0.0       0.702949         1.0
# 5            0.0         0.0           0.0       0.702949         1.0
# 6            0.0         0.0           0.0       0.702949         1.0
# 7            0.0         0.0           0.0       0.702949         1.0
# 8            0.0         0.0           0.0       0.702515         1.0
# 9            0.0         0.0           0.0       0.702515         1.0
#
#    4.0_f1-score  5.0_precision  5.0_recall  5.0_f1-score  accuracy
# ...

# %%
one_r.fit(X_ohe, y)
one_r.tree_

# %%
from sklearn import tree
tree.plot_tree(one_r)
# Out:
# [Text(0.5, 0.75, 'x[3] <= 1.5\ngini = 0.44\nsamples = 23063\nvalue = [5864, 16208, 991]'),
#  Text(0.25, 0.25, 'gini = 0.452\nsamples = 17602\nvalue = [4900, 12063, 639]'),
#  Text(0.75, 0.25, 'gini = 0.389\nsamples = 5461\nvalue = [964, 4145, 352]')]
