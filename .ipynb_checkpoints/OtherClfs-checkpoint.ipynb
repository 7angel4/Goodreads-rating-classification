# %%
# %run Global.ipynb
# %run Helper_Functions.ipynb

# %%
train_df = pd.read_csv(DATASET_DIR + "/train_df.csv", keep_default_na=False)
train_df_ohe_full = pd.read_csv(DATASET_DIR + "/train_df_ohe_full.csv", keep_default_na=False)
train_df_ohe_selected = pd.read_csv(DATASET_DIR + "/train_df_ohe_selected.csv", keep_default_na=False)
train_df_oe = pd.read_csv(DATASET_DIR + "/train_df_oe.csv", keep_default_na=False)

# %%
y = train_df.iloc[:,-1]

X = train_df.iloc[:,:-1]
X_ohe_full = train_df_ohe_full.iloc[:,:-1]
X_ohe_selected = train_df_ohe_selected.iloc[:,:-1]
X_oe = train_df_oe.iloc[:,:-1]

# %% [markdown]
# # Kernel SVM

# %%
from sklearn import svm

# %%
# Kernel SVM is way too slow with the full feature set - let's do dimensionality reduction
from sklearn.decomposition import TruncatedSVD

tsvd = TruncatedSVD(n_components=10, random_state=30027)
X_ohe_reduced = tsvd.fit_transform(X_ohe_full)
X_ohe_reduced
# Out:
# array([[ 1.31786033e+01, -2.06713949e+00,  2.20510034e-01, ...,
#         -2.08680553e-02, -5.89233047e-03, -8.27750315e-03],
#        [ 1.27903184e+01, -1.85902390e+00,  2.36138089e+00, ...,
#         -3.15998605e-02, -1.89621797e-02, -2.42359310e-02],
#        [ 1.36778452e+01,  3.82505710e+00, -2.01776468e+00, ...,
#         -9.62945927e-03, -1.41827440e-02, -2.37164079e-02],
#        ...,
#        [ 1.22550638e+01,  1.02740297e+00, -1.66835980e+00, ...,
#         -2.24271203e-02, -1.19438799e-02,  1.85204441e-02],
#        [ 1.35912984e+01,  1.85207963e+00, -9.52745127e-01, ...,
#         -1.09030632e-02, -1.09802658e-03, -4.88873423e-03],
#        [ 1.34355711e+01, -8.51258262e-02,  1.43700951e-01, ...,
#         -2.03129192e-02, -1.03643577e-02, -2.31674017e-02]])

# %% [markdown]
# ### Kernel

# %%
# Try with Kernel SVM
RBF_svm = svm.SVC(kernel='rbf')

# tune hyperparameter C and gamma
param_grid = {'C': range(1, 101, 25), 'gamma': [0.1, 0.3, 0.5, 0.7, 0.9]}
tune_hyperparameter(RBF_svm, param_grid, X_ohe_reduced, y, cv=3)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END .....................................C=1, gamma=0.1; total time=  18.7s
# [CV] END .....................................C=1, gamma=0.1; total time=  18.5s
# [CV] END .....................................C=1, gamma=0.1; total time=  18.2s
# [CV] END .....................................C=1, gamma=0.3; total time=  18.1s
# [CV] END .....................................C=1, gamma=0.3; total time=  18.0s
# [CV] END .....................................C=1, gamma=0.3; total time=  18.4s
# [CV] END .....................................C=1, gamma=0.5; total time=  17.1s
# [CV] END .....................................C=1, gamma=0.5; total time=  17.0s
# [CV] END .....................................C=1, gamma=0.5; total time=  17.0s
# [CV] END .....................................C=1, gamma=0.7; total time=  17.0s
# [CV] END .....................................C=1, gamma=0.7; total time=  16.6s
# [CV] END .....................................C=1, gamma=0.7; total time=  17.1s
# [CV] END .....................................C=1, gamma=0.9; total time=  17.1s
# [CV] END .....................................C=1, gamma=0.9; total time=  16.6s
# [CV] END .....................................C=1, gamma=0.9; total time=  16.5s
# [CV] END ....................................C=26, gamma=0.1; total time=  43.4s
# [CV] END ....................................C=26, gamma=0.1; total time=  43.3s
# [CV] END ....................................C=26, gamma=0.1; total time=  42.9s
# [CV] END ....................................C=26, gamma=0.3; total time=  24.1s
# [CV] END ....................................C=26, gamma=0.3; total time=  25.6s
# [CV] END ....................................C=26, gamma=0.3; total time=  25.4s
# [CV] END ....................................C=26, gamma=0.5; total time=  20.0s
# [CV] END ....................................C=26, gamma=0.5; total time=  20.1s
# [CV] END ....................................C=26, gamma=0.5; total time=  19.9s
# [CV] END ....................................C=26, gamma=0.7; total time=  18.6s
# [CV] END ....................................C=26, gamma=0.7; total time=  18.9s
# [CV] END ....................................C=26, gamma=0.7; total time=  18.5s
# [CV] END ....................................C=26, gamma=0.9; total time=  19.7s
# [CV] END ....................................C=26, gamma=0.9; total time=  32.7s
# [CV] END ....................................C=26, gamma=0.9; total time= 3.4min
# [CV] END ....................................C=51, gamma=0.1; total time= 1.7min
# [CV] END ....................................C=51, gamma=0.1; total time= 1.5min
# [CV] END ....................................C=51, gamma=0.1; total time= 1.5min
# [CV] END ....................................C=51, gamma=0.3; total time=  45.9s
# [CV] END ....................................C=51, gamma=0.3; total time=  45.9s
# [CV] END ....................................C=51, gamma=0.3; total time=  44.5s
# [CV] END ....................................C=51, gamma=0.5; total time=  34.0s
# [CV] END ....................................C=51, gamma=0.5; total time=  34.7s
# [CV] END ....................................C=51, gamma=0.5; total time=  34.3s
# [CV] END ....................................C=51, gamma=0.7; total time=  31.2s
# [CV] END ....................................C=51, gamma=0.7; total time=  31.4s
# [CV] END ....................................C=51, gamma=0.7; total time=  31.0s
# [CV] END ....................................C=51, gamma=0.9; total time=  31.1s
# [CV] END ....................................C=51, gamma=0.9; total time=  31.9s
# [CV] END ....................................C=51, gamma=0.9; total time=  30.8s
# [CV] END ....................................C=76, gamma=0.1; total time= 1.8min
# [CV] END ....................................C=76, gamma=0.1; total time= 1.9min
# [CV] END ....................................C=76, gamma=0.1; total time= 1.7min
# [CV] END ....................................C=76, gamma=0.3; total time=  52.6s
# [CV] END ....................................C=76, gamma=0.3; total time=  50.7s
# [CV] END ....................................C=76, gamma=0.3; total time=  50.5s
# [CV] END ....................................C=76, gamma=0.5; total time=  35.4s
# [CV] END ....................................C=76, gamma=0.5; total time=  36.1s
# [CV] END ....................................C=76, gamma=0.5; total time=  36.1s
# [CV] END ....................................C=76, gamma=0.7; total time=  32.1s
# [CV] END ....................................C=76, gamma=0.7; total time=  32.2s
# [CV] END ....................................C=76, gamma=0.7; total time=  32.1s
# [CV] END ....................................C=76, gamma=0.9; total time=  32.6s
# [CV] END ....................................C=76, gamma=0.9; total time=  31.8s
# [CV] END ....................................C=76, gamma=0.9; total time=  31.3s
#                      params  mean_test_3.0_precision  std_test_3.0_precision  \
# 0    {'C': 1, 'gamma': 0.1}                 0.000000                0.000000
# 1    {'C': 1, 'gamma': 0.3}                 0.111111                0.157135
# 2    {'C': 1, 'gamma': 0.5}                 0.466667                0.410961
# 3    {'C': 1, 'gamma': 0.7}                 0.373016                0.040468
# 4    {'C': 1, 'gamma': 0.9}                 0.278757                0.029879
# 5   {'C': 26, 'gamma': 0.1}                 0.372294                0.263465
# 6   {'C': 26, 'gamma': 0.3}                 0.252044                0.037661
# 7   {'C': 26, 'gamma': 0.5}                 0.266889                0.026646
# 8   {'C': 26, 'gamma': 0.7}                 0.265700                0.018562
# 9   {'C': 26, 'gamma': 0.9}                 0.275530                0.014266
# 10  {'C': 51, 'gamma': 0.1}                 0.359427                0.078666
# 11  {'C': 51, 'gamma': 0.3}                 0.251424                0.041688
# 12  {'C': 51, 'gamma': 0.5}                 0.273761                0.021817
# 13  {'C': 51, 'gamma': 0.7}                 0.271621                0.012579
# 14  {'C': 51, 'gamma': 0.9}                 0.280145                0.009884
# 15  {'C': 76, 'gamma': 0.1}                 0.323934                0.059529
# 16  {'C': 76, 'gamma': 0.3}                 0.253554                0.036989
# 17  {'C': 76, 'gamma': 0.5}                 0.267404                0.018234
# 18  {'C': 76, 'gamma': 0.7}                 0.275252                0.010679
# 19  {'C': 76, 'gamma': 0.9}                 0.281382                0.008730
#
#     rank_test_3.0_precision  mean_test_3.0_recall  std_test_3.0_recall  \
# 0                        20              0.000000             0.000000
# 1                        19              0.000171             0.000241
# 2                         1              0.000512             0.000418
# 3                         2              0.002558             0.000836
# 4                         8              0.006992             0.001885
# 5                         3              0.001705             0.001276
# 6                        17              0.018077             0.003139
# 7                        14              0.036666             0.006618
# 8                        15              0.040418             0.007611
# 9                         9              0.040929             0.006888
# 10                        4              0.003070             0.000836
# 11                       18              0.024899             0.005693
# 12                       11              0.043658             0.007079
# 13                       12              0.043658             0.007129
# 14                        7              0.045022             0.008460
# 15                        5              0.004093             0.001106
# 16                       16              0.028139             0.006246
# 17                       13              0.044170             0.007275
# 18                       10              0.047069             0.009174
# 19                        6              0.047580             0.007112
#
#     rank_test_3.0_recall  mean_test_3.0_f1-score  std_test_3.0_f1-score  \
# 0                     20                0.000000               0.000000
# 1                     19                0.000341               0.000482
# 2                     18                0.001021               0.000834
# 3                     16                0.005075               0.001645
# 4                     13                0.013630               0.003616
# 5                     17                0.003394               0.002539
# 6                     12                0.033733               0.005804
# 7                      9                0.064419               0.010936
# 8                      8                0.070000               0.011851
# 9                      7                0.071090               0.010547
# 10                    15                0.006086               0.001655
# 11                    11                0.045297               0.010100
# 12                     6                0.075170               0.010987
# 13                     5                0.075019               0.010626
# 14                     3                0.077357               0.012798
# 15                    14                0.008083               0.002176
# 16                    10                0.050632               0.010847
# 17                     4                0.075702               0.011263
# 18                     2                0.080151               0.013700
# 19                     1                0.081252               0.010759
#
#     rank_test_3.0_f1-score  ...  rank_test_5.0_precision  \
# 0                       20  ...                       20
# 1                       19  ...                        7
# 2                       18  ...                        1
# 3                       16  ...                        2
# 4                       13  ...                        4
# 5                       17  ...                        3
# 6                       12  ...                        8
# 7                        9  ...                       13
# 8                        8  ...                       16
# 9                        7  ...                       17
# 10                      15  ...                        5
# 11                      11  ...                        9
# 12                       5  ...                       11
# 13                       6  ...                       12
# 14                       3  ...                       18
# 15                      14  ...                        6
# 16                      10  ...                       10
# 17                       4  ...                       14
# 18                       2  ...                       15
# 19                       1  ...                       19
#
#     mean_test_5.0_recall  std_test_5.0_recall  rank_test_5.0_recall  \
# 0               0.000000             0.000000                    20
# 1               0.007071             0.006227                    19
# 2               0.016146             0.001439                    18
# 3               0.017153             0.001416                    16
# 4               0.017153             0.001416                    16
# 5               0.035317             0.003770                     7
# 6               0.032293             0.001472                     9
# 7               0.034316             0.005188                     8
# 8               0.030269             0.002433                    12
# 9               0.027242             0.002437                    13
# 10              0.037331             0.005109                     2
# 11              0.035323             0.003820                     6
# 12              0.036333             0.004986                     4
# 13              0.032290             0.003771                    10
# 14              0.027242             0.002437                    13
# 15              0.037331             0.005109                     2
# 16              0.037343             0.007981                     1
# 17              0.036333             0.004986                     4
# 18              0.031280             0.002834                    11
# 19              0.027242             0.002437                    13
#
#     mean_test_5.0_f1-score  std_test_5.0_f1-score  rank_test_5.0_f1-score  \
# 0                 0.000000               0.000000                      20
# 1                 0.013808               0.012074                      19
# 2                 0.031559               0.002793                      18
# 3                 0.033426               0.002719                      16
# 4                 0.033329               0.002717                      17
# 5                 0.066943               0.006759                       3
# 6                 0.058025               0.002498                       9
# 7                 0.059213               0.008051                       8
# 8                 0.052732               0.004391                      12
# 9                 0.048079               0.004728                      13
# 10                0.070341               0.009234                       1
# 11                0.061364               0.006089                       7
# 12                0.062248               0.007750                       5
# 13                0.056196               0.006145                      10
# 14                0.048005               0.004819                      14
# 15                0.070072               0.009186                       2
# 16                0.063843               0.011929                       4
# 17                0.062080               0.007662                       6
# 18                0.054476               0.004888                      11
# 19                0.047937               0.004968                      15
#
#     mean_test_accuracy  std_test_accuracy  rank_test_accuracy
# 0             0.702771           0.000018                   4
# 1             0.702771           0.000108                   4
# 2             0.703118           0.000359                   2
# 3             0.702684           0.000282                   6
# 4             0.700473           0.000251                   8
# 5             0.703464           0.000239                   1
# 6             0.692538           0.001378                   9
# 7             0.685080           0.000761                  12
# 8             0.682999           0.001084                  15
# 9             0.684386           0.001489                  13
# 10            0.702857           0.000593                   3
# 11            0.688592           0.001665                  10
# 12            0.682652           0.001828                  17
# 13            0.682522           0.001898                  18
# 14            0.683649           0.001063                  14
# 15            0.702250           0.000606                   7
# 16            0.687161           0.001347                  11
# 17            0.681611           0.001013                  20
# 18            0.682045           0.001225                  19
# 19            0.682825           0.000616                  16
#
# [20 rows x 31 columns]

# %%
RBF_svm = svm.SVC(kernel='rbf', gamma=0.1, C=26)
RBF_svm.fit(X_ohe_reduced, y)
cv_evaluate(RBF_svm, X_ohe_reduced, y)
# Kernel SVM performs slightly better on weighted avg precision & recall than Linear SVM
# Out:
#               precision    recall  f1-score   support
#
#          3.0       0.50      0.00      0.00      5864
#          4.0       0.70      1.00      0.83     16208
#          5.0       0.71      0.04      0.07       991
#
#     accuracy                           0.70     23063
#    macro avg       0.64      0.35      0.30     23063
# weighted avg       0.65      0.70      0.58     23063
# array([4., 4., 4., ..., 4., 4., 4.])

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logr = LogisticRegression(solver='sag') # uses Stochastic Average Gradient descent solver

# %%
param_grid = {'max_iter': [100, 500, 1000, 5000, 10000]}
cv_results = tune_hyperparameter(logr, param_grid, X_ohe_selected, y, cv=3)
cv_results
# max_iter>=500 works well

# %%
logr = LogisticRegression(solver='sag', max_iter=100)
logr.fit(X_ohe_selected, y)
cv_evaluate(logr, X_ohe_selected, y)

# %%
selector = RFECV(snb, step=1, cv=StratifiedKFold(n_splits=10), scoring=report_scoring)
selector.fit(X_ohe_selected, y)
selector.support_

# %% [markdown]
# # Boosting with Decision Trees

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier(random_state=30027)

# %%
# Tuning using GridSearch
param_grid = {
    'learning_rate': (0.01, 0.1, 1, 10),
    'max_leaf_nodes': (3, 10, 30)}
cv_results = tune_hyperparameter(hgb, param_grid, X_oe, y, cv=5)
cv_results
# 'Best' param set: learning_rate = 0.1, max_leaf_nodes = 10

# %%
# 2nd go
hgb = HistGradientBoostingClassifier(random_state=30027, learning_rate=0.1)
param_grid = {
    'max_leaf_nodes': range(10, 30, 2)}
cv_results = tune_hyperparameter(hgb, param_grid, X_oe, y, cv=5)
cv_results
# 'Best' param set: learning_rate = 0.01, max_leaf_nodes = 10

# %%
hgb = HistGradientBoostingClassifier(random_state=30027, max_leaf_nodes=22, learning_rate=0.1)
hgb.fit(X_oe, y)
cv_evaluate(hgb, X_oe, y)

# %% [markdown]
# # Baseline - 0R & 1R

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier

# %%
# 0R
zero_r = DummyClassifier(strategy='most_frequent')
cross_val(zero_r, X, y)
cv_evaluate(zero_r, X, y)
# Out:
# DummyClassifier prediction took 0.49511194229125977 seconds
#    test_3.0_f1-score  test_4.0_f1-score  test_5.0_f1-score  test_accuracy
# 0                0.0           0.825356                0.0       0.702644
# 1                0.0           0.825356                0.0       0.702644
# 2                0.0           0.825356                0.0       0.702644
# 3                0.0           0.825567                0.0       0.702949
# 4                0.0           0.825567                0.0       0.702949
# 5                0.0           0.825567                0.0       0.702949
# 6                0.0           0.825567                0.0       0.702949
# 7                0.0           0.825567                0.0       0.702949
# 8                0.0           0.825267                0.0       0.702515
# 9                0.0           0.825267                0.0       0.702515
#               precision    recall  f1-score   support
#
#          3.0       0.00      0.00      0.00      5864
#          4.0       0.70      1.00      0.83     16208
#          5.0       0.00      0.00      0.00       991
#
#     accuracy                           0.70     23063
#    macro avg       0.23      0.33      0.28     23063
# weighted avg       0.49      0.70      0.58     23063
# array([4., 4., 4., ..., 4., 4., 4.])

# %%
# 1R
one_r = DecisionTreeClassifier(max_depth=1)
cross_val(one_r, X_ohe_full, y)
cv_evaluate(one_r, X_ohe_full, y)
# Out:
# DecisionTreeClassifier prediction took 19.714357137680054 seconds
#    test_3.0_f1-score  test_4.0_f1-score  test_5.0_f1-score  test_accuracy
# 0                0.0           0.825356                0.0       0.702644
# 1                0.0           0.825356                0.0       0.702644
# 2                0.0           0.825356                0.0       0.702644
# 3                0.0           0.825567                0.0       0.702949
# 4                0.0           0.825567                0.0       0.702949
# 5                0.0           0.825567                0.0       0.702949
# 6                0.0           0.825567                0.0       0.702949
# 7                0.0           0.825567                0.0       0.702949
# 8                0.0           0.825267                0.0       0.702515
# 9                0.0           0.825267                0.0       0.702515
#               precision    recall  f1-score   support
#
#          3.0       0.00      0.00      0.00      5864
#          4.0       0.70      1.00      0.83     16208
#          5.0       0.00      0.00      0.00       991
#
#     accuracy                           0.70     23063
#    macro avg       0.23      0.33      0.28     23063
# weighted avg       0.49      0.70      0.58     23063
# array([4., 4., 4., ..., 4., 4., 4.])
